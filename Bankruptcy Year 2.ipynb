# %%
#Data Cleaning

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

file = 'C:/Users/NETWAVE/Desktop/Codenet Project 1/bank_bankrupcy_year_data/bank_bankrupcy_year2.csv'
df_year2= pd.read_csv(file)

df_year2
# Out:
#              X1       X2        X3       X4        X5        X6        X7  \
# 0      0.174190  0.41299  0.143710  1.34800  -28.9820  0.603830  0.219460
# 1      0.146240  0.46038  0.282300  1.62940    2.5952  0.000000  0.171850
# 2      0.000595  0.22612  0.488390  3.15990   84.8740  0.191140  0.004572
# 3      0.024526  0.43236  0.275460  1.78330  -10.1050  0.569440  0.024526
# 4      0.188290  0.41504  0.342310  1.92790  -58.2740  0.000000  0.233580
# ...         ...      ...       ...      ...       ...       ...       ...
# 10498  0.002861  0.58067 -0.223860  0.51658  -31.8660  0.002861  0.002861
# 10499 -0.051968  0.55254  0.147150  2.16980   12.7480 -0.051968 -0.034361
# 10500 -0.135900  0.83954 -0.342010  0.46526 -145.3100 -0.219120 -0.131860
# 10501  0.009423  0.50028  0.261630  1.52300  -10.1580  0.009423  0.007700
# 10502 -0.001775  0.94780  0.003729  1.00450  -50.2210  0.000000  0.002565
#
#              X8       X9       X10  ...       X56       X57      X58  \
# ...

# %%
df_year2.size
# Out:
# 682695

# %%
df_year2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10503 entries, 0 to 10502
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      10503 non-null  float64
#  1   X2      10503 non-null  float64
#  2   X3      10503 non-null  float64
#  3   X4      10485 non-null  float64
#  4   X5      10478 non-null  float64
#  5   X6      10503 non-null  float64
#  6   X7      10503 non-null  float64
#  7   X8      10489 non-null  float64
#  8   X9      10500 non-null  float64
#  9   X10     10503 non-null  float64
#  10  X11     10503 non-null  float64
#  11  X12     10485 non-null  float64
#  12  X13     10460 non-null  float64
#  13  X14     10503 non-null  float64
#  14  X15     10495 non-null  float64
#  15  X16     10489 non-null  float64
#  16  X17     10489 non-null  float64
#  17  X18     10503 non-null  float64
#  18  X19     10460 non-null  float64
#  19  X20     10460 non-null  float64
# ...

# %%
df_year2.isna().sum()
# Out:
# X1       0
# X2       0
# X3       0
# X4      18
# X5      25
#       ...
# X61     17
# X62     43
# X63     18
# X64    228
# Y        0
# Length: 65, dtype: int64

# %%
df_year2.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  10503.000000  10503.000000  10503.000000  10485.000000  1.047800e+04
# mean       0.052844      0.619911      0.095490      9.980499 -1.347662e+03
# std        0.647797      6.427041      6.420056    523.691951  1.185806e+05
# min      -17.692000      0.000000   -479.730000      0.002080 -1.190300e+07
# 25%        0.000686      0.253955      0.017461      1.040100 -5.207075e+01
# 50%        0.043034      0.464140      0.198560      1.605600  1.579300e+00
# 75%        0.123805      0.689330      0.419545      2.959500  5.608400e+01
# max       52.652000    480.730000     17.708000  53433.000000  6.854400e+05
#
#                  X6            X7            X8            X9           X10  \
# count  10503.000000  10503.000000  10489.000000  10500.000000  10503.000000
# mean      -0.121159      0.065624     19.140113      1.819254      0.366093
# ...

# %%
df_year2Med = df_year2.fillna(df_year2.median())
df_year2Med
# Out:
#              X1       X2        X3       X4        X5        X6        X7  \
# 0      0.174190  0.41299  0.143710  1.34800  -28.9820  0.603830  0.219460
# 1      0.146240  0.46038  0.282300  1.62940    2.5952  0.000000  0.171850
# 2      0.000595  0.22612  0.488390  3.15990   84.8740  0.191140  0.004572
# 3      0.024526  0.43236  0.275460  1.78330  -10.1050  0.569440  0.024526
# 4      0.188290  0.41504  0.342310  1.92790  -58.2740  0.000000  0.233580
# ...         ...      ...       ...      ...       ...       ...       ...
# 10498  0.002861  0.58067 -0.223860  0.51658  -31.8660  0.002861  0.002861
# 10499 -0.051968  0.55254  0.147150  2.16980   12.7480 -0.051968 -0.034361
# 10500 -0.135900  0.83954 -0.342010  0.46526 -145.3100 -0.219120 -0.131860
# 10501  0.009423  0.50028  0.261630  1.52300  -10.1580  0.009423  0.007700
# 10502 -0.001775  0.94780  0.003729  1.00450  -50.2210  0.000000  0.002565
#
#              X8       X9       X10  ...       X56       X57      X58  \
# ...

# %%
df_year2Med.isna().sum()
# Out:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
#       ..
# X61    0
# X62    0
# X63    0
# X64    0
# Y      0
# Length: 65, dtype: int64

# %%
df_year2Med.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  10503.000000  10503.000000  10503.000000  10503.000000  1.050300e+04
# mean       0.052844      0.619911      0.095490      9.966146 -1.344451e+03
# std        0.647797      6.427041      6.420056    523.243080  1.184394e+05
# min      -17.692000      0.000000   -479.730000      0.002080 -1.190300e+07
# 25%        0.000686      0.253955      0.017461      1.040900 -5.196150e+01
# 50%        0.043034      0.464140      0.198560      1.605600  1.579300e+00
# 75%        0.123805      0.689330      0.419545      2.952450  5.588350e+01
# max       52.652000    480.730000     17.708000  53433.000000  6.854400e+05
#
#                  X6            X7            X8            X9           X10  \
# count  10503.000000  10503.000000  10503.000000  10503.000000  10503.000000
# mean      -0.121159      0.065624     19.116081      1.819077      0.366093
# ...

# %%
df_year2Med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10503 entries, 0 to 10502
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      10503 non-null  float64
#  1   X2      10503 non-null  float64
#  2   X3      10503 non-null  float64
#  3   X4      10503 non-null  float64
#  4   X5      10503 non-null  float64
#  5   X6      10503 non-null  float64
#  6   X7      10503 non-null  float64
#  7   X8      10503 non-null  float64
#  8   X9      10503 non-null  float64
#  9   X10     10503 non-null  float64
#  10  X11     10503 non-null  float64
#  11  X12     10503 non-null  float64
#  12  X13     10503 non-null  float64
#  13  X14     10503 non-null  float64
#  14  X15     10503 non-null  float64
#  15  X16     10503 non-null  float64
#  16  X17     10503 non-null  float64
#  17  X18     10503 non-null  float64
#  18  X19     10503 non-null  float64
#  19  X20     10503 non-null  float64
# ...

# %%
df_year2Med.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10498    False
# 10499    False
# 10500    False
# 10501    False
# 10502    False
# Length: 10503, dtype: bool

# %%
# Supress warnings

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)


sb.boxplot(df_year2Med['X1'])
# Out:
# <AxesSubplot:xlabel='X1'>

# %%
cat_features=df_year2Med.select_dtypes(exclude=np.number).columns
cont_features=df_year2Med.select_dtypes(include=[np.number,'float64','int64']).columns

features=print(df_year2Med.columns)


cont_dummy=cont_features#.drop('store_and_fwd_flag')
plt.figure(figsize=(20,16))
for index, col in enumerate(cont_dummy, start=1):
    plt.subplot(8,9,index)
    plt.title(col)
    ax = sb.boxplot(df_year2Med[col])
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21',
#        'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
#        'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40', 'X41',
#        'X42', 'X43', 'X44', 'X45', 'X46', 'X47', 'X48', 'X49', 'X50', 'X51',
#        'X52', 'X53', 'X54', 'X55', 'X56', 'X57', 'X58', 'X59', 'X60', 'X61',
#        'X62', 'X63', 'X64', 'Y'],
#       dtype='object')

# %%
#Treating outliers

df_year2Med
# Out:
#              X1       X2        X3       X4        X5        X6        X7  \
# 0      0.174190  0.41299  0.143710  1.34800  -28.9820  0.603830  0.219460
# 1      0.146240  0.46038  0.282300  1.62940    2.5952  0.000000  0.171850
# 2      0.000595  0.22612  0.488390  3.15990   84.8740  0.191140  0.004572
# 3      0.024526  0.43236  0.275460  1.78330  -10.1050  0.569440  0.024526
# 4      0.188290  0.41504  0.342310  1.92790  -58.2740  0.000000  0.233580
# ...         ...      ...       ...      ...       ...       ...       ...
# 10498  0.002861  0.58067 -0.223860  0.51658  -31.8660  0.002861  0.002861
# 10499 -0.051968  0.55254  0.147150  2.16980   12.7480 -0.051968 -0.034361
# 10500 -0.135900  0.83954 -0.342010  0.46526 -145.3100 -0.219120 -0.131860
# 10501  0.009423  0.50028  0.261630  1.52300  -10.1580  0.009423  0.007700
# 10502 -0.001775  0.94780  0.003729  1.00450  -50.2210  0.000000  0.002565
#
#              X8       X9       X10  ...       X56       X57      X58  \
# ...

# %%
#Removing the feature Y

subData2 = df_year2Med.iloc[:, 0:64]
subData2
# Out:
#              X1       X2        X3       X4        X5        X6        X7  \
# 0      0.174190  0.41299  0.143710  1.34800  -28.9820  0.603830  0.219460
# 1      0.146240  0.46038  0.282300  1.62940    2.5952  0.000000  0.171850
# 2      0.000595  0.22612  0.488390  3.15990   84.8740  0.191140  0.004572
# 3      0.024526  0.43236  0.275460  1.78330  -10.1050  0.569440  0.024526
# 4      0.188290  0.41504  0.342310  1.92790  -58.2740  0.000000  0.233580
# ...         ...      ...       ...      ...       ...       ...       ...
# 10498  0.002861  0.58067 -0.223860  0.51658  -31.8660  0.002861  0.002861
# 10499 -0.051968  0.55254  0.147150  2.16980   12.7480 -0.051968 -0.034361
# 10500 -0.135900  0.83954 -0.342010  0.46526 -145.3100 -0.219120 -0.131860
# 10501  0.009423  0.50028  0.261630  1.52300  -10.1580  0.009423  0.007700
# 10502 -0.001775  0.94780  0.003729  1.00450  -50.2210  0.000000  0.002565
#
#              X8       X9       X10  ...       X55       X56       X57  \
# ...

# %%
Q1 = subData2.quantile(0.25)
Q3 = subData2.quantile(0.75)

# calculate the IQR
IQR = Q3 - Q1
IQR

lbound = Q1 - 1.5 * IQR
ubound = Q3 + 1.5 * IQR

def outlier_limits(col):
    Q3, Q1 = np.nanpercentile(col, [75, 25])
    IQR = Q3 -Q1
    ubound = Q3 + 1.5*IQR
    lbound = Q1 - 1.5*IQR
    return ubound, lbound

# %%
# convert outlier values to missing values

for column in subData2.columns:
    if subData2[column].dtype !='object':
        ubound, lbound = outlier_limits(subData2[column])
        subData2[column] = np.where((subData2[column] > ubound) | (subData2[column] < lbound), np.nan, subData2[column])

# %%
# check for missing values

subData2.isnull().sum()
# Out:
# X1     1266
# X2      290
# X3      271
# X4     1118
# X5     1567
#        ...
# X60    1284
# X61    1005
# X62     793
# X63     886
# X64    1383
# Length: 64, dtype: int64

# %%
# Replace missing values removed from outliers with median

dfNew_year2 = subData2.fillna(subData2.median())

# %%
# check if no missing value

dfNew_year2.isnull().sum()
# Out:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
#       ..
# X60    0
# X61    0
# X62    0
# X63    0
# X64    0
# Length: 64, dtype: int64

# %%
dfNew_year2
# Out:
#              X1       X2        X3       X4        X5        X6        X7  \
# 0      0.174190  0.41299  0.143710  1.34800  -28.9820  0.000000  0.219460
# 1      0.146240  0.46038  0.282300  1.62940    2.5952  0.000000  0.171850
# 2      0.000595  0.22612  0.488390  3.15990   84.8740  0.000000  0.004572
# 3      0.024526  0.43236  0.275460  1.78330  -10.1050  0.000000  0.024526
# 4      0.188290  0.41504  0.342310  1.92790  -58.2740  0.000000  0.233580
# ...         ...      ...       ...      ...       ...       ...       ...
# 10498  0.002861  0.58067 -0.223860  0.51658  -31.8660  0.002861  0.002861
# 10499 -0.051968  0.55254  0.147150  2.16980   12.7480 -0.051968 -0.034361
# 10500 -0.135900  0.83954 -0.342010  0.46526 -145.3100  0.000000 -0.131860
# 10501  0.009423  0.50028  0.261630  1.52300  -10.1580  0.009423  0.007700
# 10502 -0.001775  0.94780  0.003729  1.00450  -50.2210  0.000000  0.002565
#
#              X8       X9       X10  ...      X55       X56       X57      X58  \
# ...

# %%
#using boxplot to check for changes after treating outliers

sb.boxplot(dfNew_year2['X1'])
# Out:
# <AxesSubplot:xlabel='X1'>

# %%
cat_features=dfNew_year2.select_dtypes(exclude=np.number).columns
cont_features=dfNew_year2.select_dtypes(include=[np.number,'float64','int64']).columns

features=print(dfNew_year2.columns)


cont_dummy=cont_features#.drop('store_and_fwd_flag')
plt.figure(figsize=(20,16))
for index, col in enumerate(cont_dummy, start=1):
    plt.subplot(8,9,index)
    plt.title(col)
    ax = sb.boxplot(dfNew_year2[col])
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21',
#        'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
#        'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40', 'X41',
#        'X42', 'X43', 'X44', 'X45', 'X46', 'X47', 'X48', 'X49', 'X50', 'X51',
#        'X52', 'X53', 'X54', 'X55', 'X56', 'X57', 'X58', 'X59', 'X60', 'X61',
#        'X62', 'X63', 'X64'],
#       dtype='object')

# %%
#Transfroming the data

dfNew_year2
# Out:
#              X1       X2        X3       X4        X5        X6        X7  \
# 0      0.174190  0.41299  0.143710  1.34800  -28.9820  0.000000  0.219460
# 1      0.146240  0.46038  0.282300  1.62940    2.5952  0.000000  0.171850
# 2      0.000595  0.22612  0.488390  3.15990   84.8740  0.000000  0.004572
# 3      0.024526  0.43236  0.275460  1.78330  -10.1050  0.000000  0.024526
# 4      0.188290  0.41504  0.342310  1.92790  -58.2740  0.000000  0.233580
# ...         ...      ...       ...      ...       ...       ...       ...
# 10498  0.002861  0.58067 -0.223860  0.51658  -31.8660  0.002861  0.002861
# 10499 -0.051968  0.55254  0.147150  2.16980   12.7480 -0.051968 -0.034361
# 10500 -0.135900  0.83954 -0.342010  0.46526 -145.3100  0.000000 -0.131860
# 10501  0.009423  0.50028  0.261630  1.52300  -10.1580  0.009423  0.007700
# 10502 -0.001775  0.94780  0.003729  1.00450  -50.2210  0.000000  0.002565
#
#              X8       X9       X10  ...      X55       X56       X57      X58  \
# ...

# %%
dfNew_year2.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  10503.000000  10503.000000  10503.000000  10503.000000  10503.000000
# mean       0.055251      0.471254      0.227216      1.779579      2.015393
# std        0.087420      0.270828      0.287719      1.140095     69.911768
# min       -0.183050      0.000000     -0.583670      0.002080   -213.500000
# 25%        0.008169      0.253955      0.038011      1.040900    -31.855500
# 50%        0.044014      0.454290      0.207355      1.456600      1.476250
# 75%        0.101015      0.661980      0.419380      2.196600     34.895500
# max        0.308150      1.341900      1.000000      5.818900    217.510000
#
#                  X6            X7            X8            X9           X10  \
# count  10503.000000  10503.000000  10503.000000  10503.000000  10503.000000
# mean       0.008607      0.064904      1.355088      1.413436      0.512762
# ...

# %%
#comparing the minimum values and the maximum values across the features, the values are too wide apart from each other.
#Therefore, rescaling will be done for the data

# Rescale data (between 0 and 1)
from pandas import read_csv
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
dfNew_year2.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21',
#        'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
#        'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40', 'X41',
#        'X42', 'X43', 'X44', 'X45', 'X46', 'X47', 'X48', 'X49', 'X50', 'X51',
#        'X52', 'X53', 'X54', 'X55', 'X56', 'X57', 'X58', 'X59', 'X60', 'X61',
#        'X62', 'X63', 'X64'],
#       dtype='object')

# %%
array = dfNew_year2.values
# separate array into input and output components
X = array[:,0:64]
#Y = array[:,]
scaler = MinMaxScaler(feature_range=(0, 1))
rescaledX = scaler.fit_transform(X)
# summarize transformed data
set_printoptions(precision=3)

print(rescaledX[0:5,:])
# Out:
# [[0.727 0.308 0.459 0.231 0.428 0.374 0.763 0.374 0.33  0.601 0.721 0.609
#   0.645 0.763 0.425 0.613 0.322 0.763 0.729 0.274 0.542 0.881 0.697 0.904
#   0.66  0.587 0.493 0.421 0.981 0.482 0.69  0.398 0.309 0.369 0.885 0.412
#   0.47  0.519 0.834 0.286 0.402 0.828 0.377 0.387 0.643 0.23  0.369 0.892
#   0.852 0.291 0.395 0.398 0.434 0.389 0.411 0.694 0.725 0.292 0.37  0.237
#   0.319 0.361 0.247 0.197]
#  [0.67  0.343 0.547 0.28  0.501 0.374 0.678 0.38  0.441 0.658 0.649 0.543
#   0.61  0.678 0.455 0.537 0.289 0.678 0.684 0.444 0.504 0.676 0.676 0.476
#   0.477 0.529 0.433 0.544 0.537 0.496 0.655 0.415 0.301 0.527 0.448 0.365
#   0.47  0.587 0.447 0.264 0.451 0.676 0.59  0.591 0.528 0.26  0.474 0.699
#   0.707 0.343 0.429 0.415 0.589 0.556 0.57  0.42  0.625 0.428 0.37  0.146
#   0.209 0.438 0.204 0.29 ]
#  [0.374 0.169 0.677 0.543 0.692 0.374 0.379 0.592 0.278 0.759 0.365 0.381
#   0.397 0.379 0.613 0.423 0.583 0.379 0.38  0.393 0.249 0.444 0.374 0.53
# ...

# %%
resc_df2 = pd.DataFrame(rescaledX, columns =['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
       'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
       'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29',
       'X30', 'X31', 'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39',
       'X40', 'X41', 'X42', 'X43', 'X44', 'X45', 'X46', 'X47', 'X48', 'X49',
       'X50', 'X51', 'X52', 'X53', 'X54', 'X55', 'X56', 'X57', 'X58', 'X59',
       'X60', 'X61', 'X62', 'X63', 'X64'])

resc_df2
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.727280  0.307765  0.459300  0.231384  0.428106  0.374021  0.762933
# 1      0.670379  0.343081  0.546812  0.279761  0.501369  0.374021  0.677916
# 2      0.373871  0.168507  0.676947  0.542877  0.692267  0.374021  0.379211
# 3      0.422590  0.322200  0.542493  0.306219  0.471903  0.374021  0.414843
# 4      0.755985  0.309293  0.584705  0.331078  0.360145  0.374021  0.788147
# ...         ...       ...       ...       ...       ...       ...       ...
# 10498  0.378483  0.432722  0.227200  0.088450  0.421415  0.383894  0.376156
# 10499  0.266861  0.411759  0.461472  0.372664  0.524925  0.194679  0.309689
# 10500  0.095989  0.625635  0.152595  0.079628  0.158210  0.374021  0.135587
# 10501  0.391841  0.372815  0.533760  0.261469  0.471780  0.406538  0.384797
# 10502  0.369046  0.706312  0.370910  0.172331  0.378829  0.374021  0.375628
#
# ...

# %%
resc_df2.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  10503.000000  10503.000000  10503.000000  10503.000000  10503.000000
# mean       0.485140      0.351184      0.512030      0.305579      0.500024
# std        0.177973      0.201824      0.181678      0.196000      0.162205
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.389290      0.189250      0.392557      0.178589      0.421439
# 50%        0.462264      0.338542      0.499489      0.250054      0.498773
# 75%        0.578308      0.493315      0.633371      0.377271      0.576310
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  X6            X7            X8            X9           X10  \
# count  10503.000000  10503.000000  10503.000000  10503.000000  10503.000000
# mean       0.403725      0.486945      0.401637      0.389519      0.637736
# ...

# %%
# Exploring continuous data

import matplotlib.pyplot as plt
plt.figure(figsize=(20,16))
for index, col in enumerate(cont_features, start=1):
    plt.subplot(8,9,index)
    plt.title(col)
    sb.distplot(resc_df2[col], kde_kws={'bw':0.5}) # bw is bandwith

# %%
#following the rule that if the mean and the 50th percentile are identical and if the mean is identical
#with the middle point of the minimum value and the maximum value,
#a few of the features do not have normal distribution, then the data will be normalized

# Normalize data (length of 1)
from sklearn.preprocessing import Normalizer
from pandas import read_csv
from numpy import set_printoptions
 
array = resc_df2.values
# separate array into input and output components
X = array[:,0:64]
#Y = array[:,]
scaler = Normalizer().fit(X)
normalizedX = scaler.transform(X)
# summarize transformed data
set_printoptions(precision=3)
print(normalizedX[0:5,:])
# Out:
# [[0.164 0.069 0.103 0.052 0.096 0.084 0.172 0.084 0.074 0.135 0.162 0.137
#   0.145 0.172 0.096 0.138 0.072 0.172 0.164 0.062 0.122 0.198 0.157 0.203
#   0.148 0.132 0.111 0.095 0.221 0.108 0.155 0.089 0.07  0.083 0.199 0.093
#   0.106 0.117 0.188 0.064 0.09  0.186 0.085 0.087 0.145 0.052 0.083 0.2
#   0.191 0.065 0.089 0.09  0.098 0.087 0.093 0.156 0.163 0.066 0.083 0.053
#   0.072 0.081 0.056 0.044]
#  [0.165 0.084 0.135 0.069 0.123 0.092 0.167 0.094 0.109 0.162 0.16  0.133
#   0.15  0.167 0.112 0.132 0.071 0.167 0.168 0.109 0.124 0.166 0.166 0.117
#   0.117 0.13  0.106 0.134 0.132 0.122 0.161 0.102 0.074 0.13  0.11  0.09
#   0.116 0.144 0.11  0.065 0.111 0.166 0.145 0.145 0.13  0.064 0.117 0.172
#   0.174 0.084 0.106 0.102 0.145 0.137 0.14  0.103 0.154 0.105 0.091 0.036
#   0.051 0.108 0.05  0.071]
#  [0.099 0.045 0.179 0.144 0.183 0.099 0.101 0.157 0.074 0.201 0.097 0.101
#   0.105 0.101 0.162 0.112 0.154 0.101 0.101 0.104 0.066 0.118 0.099 0.141
# ...

# %%
newNorm_df2 = pd.DataFrame(normalizedX, columns =['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
       'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
       'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29',
       'X30', 'X31', 'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39',
       'X40', 'X41', 'X42', 'X43', 'X44', 'X45', 'X46', 'X47', 'X48', 'X49',
       'X50', 'X51', 'X52', 'X53', 'X54', 'X55', 'X56', 'X57', 'X58', 'X59',
       'X60', 'X61', 'X62', 'X63', 'X64'])

newNorm_df2
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.163514  0.069195  0.103264  0.052022  0.096251  0.084091  0.171529
# 1      0.164934  0.084408  0.134532  0.068830  0.123352  0.092020  0.166788
# 2      0.099088  0.044660  0.179414  0.143881  0.183474  0.099128  0.100504
# 3      0.112436  0.085726  0.144338  0.081474  0.125557  0.099514  0.110375
# 4      0.162607  0.066527  0.125766  0.071213  0.077465  0.080449  0.169525
# ...         ...       ...       ...       ...       ...       ...       ...
# 10498  0.113790  0.130097  0.068307  0.026592  0.126698  0.115417  0.113091
# 10499  0.086634  0.133674  0.149813  0.120982  0.170413  0.063201  0.100538
# 10500  0.032852  0.214120  0.052225  0.027252  0.054146  0.128006  0.046404
# 10501  0.112132  0.106687  0.152744  0.074824  0.135007  0.116337  0.110116
# 10502  0.101787  0.194809  0.102301  0.047531  0.104485  0.103159  0.103602
#
# ...

# %%
# Exploring continuous data

import matplotlib.pyplot as plt
plt.figure(figsize=(20,16))
for index, col in enumerate(cont_features, start=1):
    plt.subplot(8,9,index)
    plt.title(col)
    sb.distplot(newNorm_df2[col], kde_kws={'bw':0.5}) # bw is bandwith

# %%
newNorm_df2.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  10503.000000  10503.000000  10503.000000  10503.000000  10503.000000
# mean       0.125041      0.097149      0.133665      0.078295      0.131309
# std        0.036216      0.062438      0.043352      0.045522      0.039145
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.107833      0.046308      0.107466      0.049871      0.111899
# 50%        0.123943      0.090766      0.132340      0.065335      0.132918
# 75%        0.145798      0.136519      0.158639      0.095973      0.152436
# max        0.260523      0.347270      0.315179      0.297954      0.296664
#
#                  X6            X7            X8            X9           X10  \
# count  10503.000000  10503.000000  10503.000000  10503.000000  10503.000000
# mean       0.107461      0.125292      0.104842      0.102962      0.167157
# ...

# %%
newNorm_df2['Y']=df_year2Med['Y']

newNorm_df2
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.163514  0.069195  0.103264  0.052022  0.096251  0.084091  0.171529
# 1      0.164934  0.084408  0.134532  0.068830  0.123352  0.092020  0.166788
# 2      0.099088  0.044660  0.179414  0.143881  0.183474  0.099128  0.100504
# 3      0.112436  0.085726  0.144338  0.081474  0.125557  0.099514  0.110375
# 4      0.162607  0.066527  0.125766  0.071213  0.077465  0.080449  0.169525
# ...         ...       ...       ...       ...       ...       ...       ...
# 10498  0.113790  0.130097  0.068307  0.026592  0.126698  0.115417  0.113091
# 10499  0.086634  0.133674  0.149813  0.120982  0.170413  0.063201  0.100538
# 10500  0.032852  0.214120  0.052225  0.027252  0.054146  0.128006  0.046404
# 10501  0.112132  0.106687  0.152744  0.074824  0.135007  0.116337  0.110116
# 10502  0.101787  0.194809  0.102301  0.047531  0.104485  0.103159  0.103602
#
# ...

# %%
#Feature Selection

# %%
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

array = newNorm_df2.values
X = array[:, 0:64]
Y = array[:, 64]
#feature extraction
model = LogisticRegression()# Algorithm

rfe = RFE(model)
fit = rfe.fit(X, Y)
print("Num Features: {}".format(fit.n_features_))
print("Selected Features: {}".format(fit.support_))
print("Feature Ranking: {}".format(fit.ranking_))
# Out:
# Num Features: 32
# Selected Features: [ True  True  True  True False  True False False  True  True False  True
#   True False False  True  True False False  True  True False False  True
#  False  True  True False False False False False  True False  True  True
#   True False  True False False False  True False  True  True False  True
#   True  True  True False False False  True False False False False False
#   True  True  True False]
# Feature Ranking: [ 1  1  1  1 11  1 33 14  1  1 20  1  1 31 28  1  1 32  3  1  1 13 27  1
#   9  1  1 24 25 15 19 29  1  2  1  1  1 18  1 16  4 21  1 10  1  1 26  1
#   1  1  1 17  5 22  1  8  6  7 23 30  1  1  1 12]
