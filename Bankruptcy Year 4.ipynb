# %%
#Data Cleaning

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

file = 'C:/Users/NETWAVE/Desktop/Codenet Project 1/bank_bankrupcy_year_data/bank_bankrupcy_year4.csv'
df_year4= pd.read_csv(file)

df_year4
# Out:
#             X1       X2        X3       X4        X5        X6        X7  \
# 0     0.088238  0.55472  0.011340  1.02050  -66.5200  0.342040  0.109490
# 1    -0.006202  0.48465  0.232980  1.59980    6.1825  0.000000 -0.006202
# 2     0.130240  0.22142  0.577510  3.60820  120.0400  0.187640  0.162120
# 3    -0.089951  0.88700  0.269270  1.52220  -55.9920 -0.073957 -0.089951
# 4     0.048179  0.55041  0.107650  1.24370  -22.9590  0.000000  0.059280
# ...        ...      ...       ...      ...       ...       ...       ...
# 5905  0.012898  0.70621  0.038857  1.17220  -18.9070  0.000000  0.013981
# 5906 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.578050 -0.578050
# 5907 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.179050 -0.154930
# 5908 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.108860 -0.109180
# 5909 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.105370 -0.109940
#
#            X8       X9       X10  ...       X56       X57      X58       X59  \
# ...

# %%
df_year4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5910 entries, 0 to 5909
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      5907 non-null   float64
#  1   X2      5907 non-null   float64
#  2   X3      5907 non-null   float64
#  3   X4      5889 non-null   float64
#  4   X5      5899 non-null   float64
#  5   X6      5907 non-null   float64
#  6   X7      5907 non-null   float64
#  7   X8      5892 non-null   float64
#  8   X9      5909 non-null   float64
#  9   X10     5907 non-null   float64
#  10  X11     5907 non-null   float64
#  11  X12     5889 non-null   float64
#  12  X13     5910 non-null   float64
#  13  X14     5907 non-null   float64
#  14  X15     5904 non-null   float64
#  15  X16     5892 non-null   float64
#  16  X17     5892 non-null   float64
#  17  X18     5907 non-null   float64
#  18  X19     5910 non-null   float64
#  19  X20     5910 non-null   float64
# ...

# %%
df_year4.isna().sum()
# Out:
# X1       3
# X2       3
# X3       3
# X4      21
# X5      11
#       ...
# X61     15
# X62      0
# X63     21
# X64    107
# Y        0
# Length: 65, dtype: int64

# %%
df_year4.describe()
# Out:
#                 X1           X2           X3           X4            X5  \
# count  5907.000000  5907.000000  5907.000000  5889.000000  5.899000e+03
# mean     -0.022347     0.465086     0.189155     4.892476  1.940676e+01
# std       6.163655     5.751283     1.177729    91.434574  2.152932e+04
# min    -463.890000  -430.870000   -72.067000    -0.403110 -1.076400e+06
# 25%       0.003965     0.255355     0.043953     1.093700 -4.383650e+01
# 50%       0.046670     0.451750     0.219440     1.651700  4.914900e-01
# 75%       0.117050     0.661635     0.418430     2.931000  4.876500e+01
# max      87.459000    72.416000    28.336000  6845.800000  1.250100e+06
#
#                 X6           X7           X8           X9          X10  ...  \
# count  5907.000000  5907.000000  5892.000000  5909.000000  5907.000000  ...
# mean      0.022584    -0.111951     5.737741     1.588322     0.545580  ...
# std       9.992080     9.057135   102.355101     1.548390     5.763742  ...
# ...

# %%
df_year4Med = df_year4.fillna(df_year4.median())
df_year4Med
# Out:
#             X1       X2        X3       X4        X5        X6        X7  \
# 0     0.088238  0.55472  0.011340  1.02050  -66.5200  0.342040  0.109490
# 1    -0.006202  0.48465  0.232980  1.59980    6.1825  0.000000 -0.006202
# 2     0.130240  0.22142  0.577510  3.60820  120.0400  0.187640  0.162120
# 3    -0.089951  0.88700  0.269270  1.52220  -55.9920 -0.073957 -0.089951
# 4     0.048179  0.55041  0.107650  1.24370  -22.9590  0.000000  0.059280
# ...        ...      ...       ...      ...       ...       ...       ...
# 5905  0.012898  0.70621  0.038857  1.17220  -18.9070  0.000000  0.013981
# 5906 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.578050 -0.578050
# 5907 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.179050 -0.154930
# 5908 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.108860 -0.109180
# 5909 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.105370 -0.109940
#
#            X8       X9       X10  ...       X56       X57      X58       X59  \
# ...

# %%
df_year4Med.isna().sum()
# Out:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
#       ..
# X61    0
# X62    0
# X63    0
# X64    0
# Y      0
# Length: 65, dtype: int64

# %%
df_year4Med.describe()
# Out:
#                 X1           X2           X3           X4            X5  \
# count  5910.000000  5910.000000  5910.000000  5910.000000  5.910000e+03
# mean     -0.022312     0.465079     0.189170     4.880960  1.937155e+01
# std       6.162090     5.749823     1.177430    91.272158  2.150927e+04
# min    -463.890000  -430.870000   -72.067000    -0.403110 -1.076400e+06
# 25%       0.003969     0.255370     0.043976     1.097200 -4.369900e+01
# 50%       0.046670     0.451750     0.219440     1.651700  4.914900e-01
# 75%       0.117040     0.661530     0.418318     2.922650  4.865500e+01
# max      87.459000    72.416000    28.336000  6845.800000  1.250100e+06
#
#                 X6           X7           X8           X9          X10  ...  \
# count  5910.000000  5910.000000  5910.000000  5910.000000  5910.000000  ...
# mean      0.022572    -0.111866     5.723766     1.588246     0.545569  ...
# std       9.989544     9.054837   102.199398     1.548270     5.762279  ...
# ...

# %%
df_year4Med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5910 entries, 0 to 5909
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      5910 non-null   float64
#  1   X2      5910 non-null   float64
#  2   X3      5910 non-null   float64
#  3   X4      5910 non-null   float64
#  4   X5      5910 non-null   float64
#  5   X6      5910 non-null   float64
#  6   X7      5910 non-null   float64
#  7   X8      5910 non-null   float64
#  8   X9      5910 non-null   float64
#  9   X10     5910 non-null   float64
#  10  X11     5910 non-null   float64
#  11  X12     5910 non-null   float64
#  12  X13     5910 non-null   float64
#  13  X14     5910 non-null   float64
#  14  X15     5910 non-null   float64
#  15  X16     5910 non-null   float64
#  16  X17     5910 non-null   float64
#  17  X18     5910 non-null   float64
#  18  X19     5910 non-null   float64
#  19  X20     5910 non-null   float64
# ...

# %%
df_year4Med.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5905    False
# 5906    False
# 5907    False
# 5908    False
# 5909    False
# Length: 5910, dtype: bool

# %%
# Supress warnings

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)


sb.boxplot(df_year4Med['X1'])
# Out:
# <AxesSubplot:xlabel='X1'>

# %%
cat_features=df_year4Med.select_dtypes(exclude=np.number).columns
cont_features=df_year4Med.select_dtypes(include=[np.number,'float64','int64']).columns

features=print(df_year4Med.columns)


cont_dummy=cont_features#.drop('store_and_fwd_flag')
plt.figure(figsize=(20,16))
for index, col in enumerate(cont_dummy, start=1):
    plt.subplot(8,9,index)
    plt.title(col)
    ax = sb.boxplot(df_year4Med[col])
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21',
#        'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
#        'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40', 'X41',
#        'X42', 'X43', 'X44', 'X45', 'X46', 'X47', 'X48', 'X49', 'X50', 'X51',
#        'X52', 'X53', 'X54', 'X55', 'X56', 'X57', 'X58', 'X59', 'X60', 'X61',
#        'X62', 'X63', 'X64', 'Y'],
#       dtype='object')

# %%
#Treating outliers

df_year4Med
# Out:
#             X1       X2        X3       X4        X5        X6        X7  \
# 0     0.088238  0.55472  0.011340  1.02050  -66.5200  0.342040  0.109490
# 1    -0.006202  0.48465  0.232980  1.59980    6.1825  0.000000 -0.006202
# 2     0.130240  0.22142  0.577510  3.60820  120.0400  0.187640  0.162120
# 3    -0.089951  0.88700  0.269270  1.52220  -55.9920 -0.073957 -0.089951
# 4     0.048179  0.55041  0.107650  1.24370  -22.9590  0.000000  0.059280
# ...        ...      ...       ...      ...       ...       ...       ...
# 5905  0.012898  0.70621  0.038857  1.17220  -18.9070  0.000000  0.013981
# 5906 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.578050 -0.578050
# 5907 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.179050 -0.154930
# 5908 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.108860 -0.109180
# 5909 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.105370 -0.109940
#
#            X8       X9       X10  ...       X56       X57      X58       X59  \
# ...

# %%
#Removing the feature Y

subData4 = df_year4Med.iloc[:, 0:64]
subData4
# Out:
#             X1       X2        X3       X4        X5        X6        X7  \
# 0     0.088238  0.55472  0.011340  1.02050  -66.5200  0.342040  0.109490
# 1    -0.006202  0.48465  0.232980  1.59980    6.1825  0.000000 -0.006202
# 2     0.130240  0.22142  0.577510  3.60820  120.0400  0.187640  0.162120
# 3    -0.089951  0.88700  0.269270  1.52220  -55.9920 -0.073957 -0.089951
# 4     0.048179  0.55041  0.107650  1.24370  -22.9590  0.000000  0.059280
# ...        ...      ...       ...      ...       ...       ...       ...
# 5905  0.012898  0.70621  0.038857  1.17220  -18.9070  0.000000  0.013981
# 5906 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.578050 -0.578050
# 5907 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.179050 -0.154930
# 5908 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.108860 -0.109180
# 5909 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.105370 -0.109940
#
#            X8       X9       X10  ...         X55       X56       X57  \
# ...

# %%
Q1 = subData4.quantile(0.25)
Q3 = subData4.quantile(0.75)

# calculate the IQR
IQR = Q3 - Q1
IQR

lbound = Q1 - 1.5 * IQR
ubound = Q3 + 1.5 * IQR

def outlier_limits(col):
    Q3, Q1 = np.nanpercentile(col, [75, 25])
    IQR = Q3 -Q1
    ubound = Q3 + 1.5*IQR
    lbound = Q1 - 1.5*IQR
    return ubound, lbound

# %%
# convert outlier values to missing values

for column in subData4.columns:
    if subData4[column].dtype !='object':
        ubound, lbound = outlier_limits(subData4[column])
        subData4[column] = np.where((subData4[column] > ubound) | (subData4[column] < lbound), np.nan, subData4[column])

# %%
# check for missing values

subData4.isnull().sum()
# Out:
# X1     688
# X2     161
# X3     187
# X4     577
# X5     671
#       ...
# X60    660
# X61    476
# X62    433
# X63    405
# X64    798
# Length: 64, dtype: int64

# %%
# Replace missing values removed from outliers with median

dfNew_year4 = subData4.fillna(subData4.median())

# %%
# check if no missing value

dfNew_year4.isnull().sum()
# Out:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
#       ..
# X60    0
# X61    0
# X62    0
# X63    0
# X64    0
# Length: 64, dtype: int64

# %%
dfNew_year4
# Out:
#             X1       X2        X3       X4        X5        X6        X7  \
# 0     0.088238  0.55472  0.011340  1.02050  -66.5200  0.000000  0.109490
# 1    -0.006202  0.48465  0.232980  1.59980    6.1825  0.000000 -0.006202
# 2     0.130240  0.22142  0.577510  3.60820  120.0400  0.187640  0.162120
# 3    -0.089951  0.88700  0.269270  1.52220  -55.9920 -0.073957 -0.089951
# 4     0.048179  0.55041  0.107650  1.24370  -22.9590  0.000000  0.059280
# ...        ...      ...       ...      ...       ...       ...       ...
# 5905  0.012898  0.70621  0.038857  1.17220  -18.9070  0.000000  0.013981
# 5906  0.047374  0.96702  0.228340  0.16576  -67.3650  0.000000  0.057213
# 5907  0.047374  1.25530 -0.275990  0.74554 -120.4400  0.000000 -0.154930
# 5908 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.108860 -0.109180
# 5909 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.105370 -0.109940
#
#            X8       X9       X10  ...         X55       X56       X57  \
# ...

# %%
#using boxplot to check for changes after treating outliers

sb.boxplot(dfNew_year4['X1'])
# Out:
# <AxesSubplot:xlabel='X1'>

# %%
cat_features=dfNew_year4.select_dtypes(exclude=np.number).columns
cont_features=dfNew_year4.select_dtypes(include=[np.number,'float64','int64']).columns

features=print
# Out:
#             X1        X2        X3        X4        X5        X6        X7  \
# 0     0.139979  0.110184  0.087779  0.058618  0.078189  0.093567  0.142719
# 1     0.100955  0.110628  0.143402  0.094775  0.146355  0.107526  0.100453
# 2     0.134311  0.036203  0.150069  0.135960  0.168216  0.165832  0.138192
# 3     0.050159  0.212333  0.157690  0.095541  0.102812  0.061516  0.057095
# 4     0.124652  0.115621  0.109838  0.071712  0.113844  0.098953  0.125550
# ...        ...       ...       ...       ...       ...       ...       ...
# 5905  0.116763  0.166466  0.109621  0.076975  0.130999  0.111037  0.115183
# 5906  0.153993  0.251901  0.162632  0.030719  0.101791  0.122708  0.154394
# 5907  0.122112  0.259298  0.041397  0.049185  0.043392  0.097304  0.016963
# 5908  0.044621  0.211453  0.126592  0.087846  0.159804  0.044323  0.054638
# 5909  0.047914  0.154157  0.113279  0.078530  0.123382  0.047729  0.054731
#
# ...

# %%
# Exploring continuous data

import matplotlib.pyplot as plt
plt.figure(figsize=(20,16))
for index, col in enumerate(cont_features, start=1):
    plt.subplot(8,9,index)
    plt.title(col)
    sb.distplot(newNorm_df4[col], kde_kws={'bw':0.5}) # bw is bandwith

# %%
newNorm_df4.describe()
# Out:
#                 X1           X2           X3           X4           X5  \
# count  5910.000000  5910.000000  5910.000000  5910.000000  5910.000000
# mean      0.124915     0.100000     0.130334     0.093757     0.128730
# std       0.034520     0.063210     0.041060     0.040530     0.039428
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.107829     0.049282     0.105422     0.067633     0.108246
# 50%       0.124237     0.093766     0.129296     0.082546     0.130493
# 75%       0.145223     0.138440     0.154129     0.109726     0.150568
# max       0.250024     0.347357     0.302912     0.320151     0.287038
#
#                 X6           X7           X8           X9          X10  ...  \
# count  5910.000000  5910.000000  5910.000000  5910.000000  5910.000000  ...
# mean      0.111909     0.124730     0.084441     0.112342     0.161051  ...
# std       0.042596     0.034282     0.043255     0.048953     0.048174  ...
# ...

# %%
newNorm_df4['Y']=df_year4Med['Y']

newNorm_df4
# Out:
#             X1        X2        X3        X4        X5        X6        X7  \
# 0     0.139979  0.110184  0.087779  0.058618  0.078189  0.093567  0.142719
# 1     0.100955  0.110628  0.143402  0.094775  0.146355  0.107526  0.100453
# 2     0.134311  0.036203  0.150069  0.135960  0.168216  0.165832  0.138192
# 3     0.050159  0.212333  0.157690  0.095541  0.102812  0.061516  0.057095
# 4     0.124652  0.115621  0.109838  0.071712  0.113844  0.098953  0.125550
# ...        ...       ...       ...       ...       ...       ...       ...
# 5905  0.116763  0.166466  0.109621  0.076975  0.130999  0.111037  0.115183
# 5906  0.153993  0.251901  0.162632  0.030719  0.101791  0.122708  0.154394
# 5907  0.122112  0.259298  0.041397  0.049185  0.043392  0.097304  0.016963
# 5908  0.044621  0.211453  0.126592  0.087846  0.159804  0.044323  0.054638
# 5909  0.047914  0.154157  0.113279  0.078530  0.123382  0.047729  0.054731
#
# ...

# %%
#Feature Selection

# %%
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

array = newNorm_df4.values
X = array[:, 0:64]
Y = array[:, 64]
#feature extraction
model = LogisticRegression()# Algorithm

rfe = RFE(model)
fit = rfe.fit(X, Y)
print("Num Features: {}".format(fit.n_features_))
print("Selected Features: {}".format(fit.support_))
print("Feature Ranking: {}".format(fit.ranking_))
# Out:
# Num Features: 32
# Selected Features: [False  True False  True False False False  True  True  True False  True
#  False False  True  True  True False False False  True  True False  True
#   True  True  True False  True  True False False False  True  True False
#   True  True False False  True False False  True False  True False False
#  False  True  True False False  True  True False  True  True False False
#   True False  True False]
# Feature Ranking: [24  1 17  1  3  9 26  1  1  1  8  1 14 12  1  1  1 19 23 27  1  1  4  1
#   1  1  1  6  1  1 18 33 21  1  1 25  1  1  5 32  1 10 22  1 15  1  7 28
#  13  1  1 20 31  1  1 29  1  1 16 11  1  2  1 30]
